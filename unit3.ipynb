# %% [markdown]
# <a href="https://colab.research.google.com/github/LebranceBW/6.S081-All-in-one/blob/main/unit3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000  --folder logs/

# %% [markdown]
# ## Train our Deep Q-Learning Agent to Play Space Invaders 👾
#
# To train an agent with RL-Baselines3-Zoo, we just need to do two things:
#
# 1. Create a hyperparameter config file that will contain our training hyperparameters called `dqn.yml`.
#
# This is a template example:
#
# ```
# SpaceInvadersNoFrameskip-v4:
#   env_wrapper:
#     - stable_baselines3.common.atari_wrappers.AtariWrapper
#   frame_stack: 4
#   policy: 'CnnPolicy'
#   n_timesteps: !!float 1e6
#   buffer_size: 100000
#   learning_rate: !!float 1e-4
#   batch_size: 32
#   learning_starts: 100000
#   target_update_interval: 1000
#   train_freq: 4
#   gradient_steps: 1
#   exploration_fraction: 0.1
#   exploration_final_eps: 0.01
#   # If True, you need to deactivate handle_timeout_termination
#   # in the replay_buffer_kwargs
#   optimize_memory_usage: False
# ```

# %% [markdown]
# # Unit 3: Deep Q-Learning with Atari Games 👾 using RL Baselines3 Zoo
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit4/thumbnail.jpg" alt="Unit 3 Thumbnail">
#
# In this notebook, **you'll train a Deep Q-Learning agent** playing Space Invaders using [RL Baselines3 Zoo](https://github.com/DLR-RM/rl-baselines3-zoo), a training framework based on [Stable-Baselines3](https://stable-baselines3.readthedocs.io/en/master/) that provides scripts for training, evaluating agents, tuning hyperparameters, plotting results and recording videos.
#
# We're using the [RL-Baselines-3 Zoo integration, a vanilla version of Deep Q-Learning](https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html) with no extensions such as Double-DQN, Dueling-DQN, and Prioritized Experience Replay.
#
# ⬇️ Here is an example of what **you will achieve** ⬇️

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/ThomasSimonini/ppo-SpaceInvadersNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# ### 🎮 Environments:
#
# - [SpacesInvadersNoFrameskip-v4](https://gymnasium.farama.org/environments/atari/space_invaders/)
#
# You can see the difference between Space Invaders versions here 👉 https://gymnasium.farama.org/environments/atari/space_invaders/#variants
#
# ### 📚 RL-Library:
#
# - [RL-Baselines3-Zoo](https://github.com/DLR-RM/rl-baselines3-zoo)

# %% [markdown]
# ## Objectives of this notebook 🏆
# At the end of the notebook, you will:
# - Be able to understand deeper **how RL Baselines3 Zoo works**.
# - Be able to **push your trained agent and the code to the Hub** with a nice video replay and an evaluation score 🔥.

# %% [markdown]
# ## This notebook is from Deep Reinforcement Learning Course
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/deep-rl-course-illustration.jpg" alt="Deep RL Course illustration"/>

# %% [markdown]
# In this free course, you will:
#
# - 📖 Study Deep Reinforcement Learning in **theory and practice**.
# - 🧑‍💻 Learn to **use famous Deep RL libraries** such as Stable Baselines3, RL Baselines3 Zoo, CleanRL and Sample Factory 2.0.
# - 🤖 Train **agents in unique environments**
#
# And more check 📚 the syllabus 👉 https://simoninithomas.github.io/deep-rl-course
#
# Don’t forget to **<a href="http://eepurl.com/ic5ZUD">sign up to the course</a>** (we are collecting your email to be able to **send you the links when each Unit is published and give you information about the challenges and updates).**
#
#
# The best way to keep in touch is to join our discord server to exchange with the community and with us 👉🏻 https://discord.gg/ydHrjt3WP5

# %% [markdown]
# ## Prerequisites 🏗️
# Before diving into the notebook, you need to:
#
# 🔲 📚 **[Study Deep Q-Learning by reading Unit 3](https://huggingface.co/deep-rl-course/unit3/introduction)**  🤗

# %% [markdown]
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# # Let's train a Deep Q-Learning agent playing Atari' Space Invaders 👾 and upload it to the Hub.
#
# We strongly recommend students **to use Google Colab for the hands-on exercises instead of running them on their personal computers**.
#
# By using Google Colab, **you can focus on learning and experimenting without worrying about the technical aspects of setting up your environments**.
#
# To validate this hands-on for the certification process, you need to push your trained model to the Hub and **get a result of >= 200**.
#
# To find your result, go to the leaderboard and find your model, **the result = mean_reward - std of reward**
#
# For more information about the certification process, check this section 👉 https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process

# %% [markdown]
# ## An advice 💡
# It's better to run this colab in a copy on your Google Drive, so that **if it timeouts** you still have the saved notebook on your Google Drive and do not need to fill everything from scratch.
#
# To do that you can either do `Ctrl + S` or `File > Save a copy in Google Drive.`
#
# Also, we're going to **train it for 90 minutes with 1M timesteps**. By typing `!nvidia-smi` will tell you what GPU you're using.
#
# And if you want to train more such 10 million steps, this will take about 9 hours, potentially resulting in Colab timing out. In that case, I recommend running this on your local computer (or somewhere else). Just click on: `File>Download`.

# %% [markdown]
# ## Set the GPU 💪
# - To **accelerate the agent's training, we'll use a GPU**. To do that, go to `Runtime > Change Runtime type`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step1.jpg" alt="GPU Step 1">

# %% [markdown]
# - `Hardware Accelerator > GPU`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step2.jpg" alt="GPU Step 2">

# %% [markdown]
# # Install RL-Baselines3 Zoo and its dependencies 📚
#
# If you see `ERROR: pip's dependency resolver does not currently take into account all the packages that are installed.` **this is normal and it's not a critical error** there's a conflict of version. But the packages we need are installed.

# %%
# !pip install git+https://github.com/DLR-RM/rl-baselines3-zoo
# Out:
# Collecting git+https://github.com/DLR-RM/rl-baselines3-zoo
#   Cloning https://github.com/DLR-RM/rl-baselines3-zoo to /tmp/pip-req-build-nyiv67fb
#   Running command git clone --filter=blob:none --quiet https://github.com/DLR-RM/rl-baselines3-zoo /tmp/pip-req-build-nyiv67fb
#   Resolved https://github.com/DLR-RM/rl-baselines3-zoo to commit ab4aadb57c6c42abcf1016318c2bebe35c4c1270
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting sb3_contrib<3.0,>=2.7.0 (from rl_zoo3==2.7.0)
#   Downloading sb3_contrib-2.7.0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: gymnasium<1.3.0,>=0.29.1 in /usr/local/lib/python3.12/dist-packages (from rl_zoo3==2.7.0) (1.2.1)
# Collecting huggingface_sb3<4.0,>=3.0 (from rl_zoo3==2.7.0)
#   Downloading huggingface_sb3-3.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from rl_zoo3==2.7.0) (4.67.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from rl_zoo3==2.7.0) (13.9.4)
# Collecting optuna>=3.0 (from rl_zoo3==2.7.0)
#   Downloading optuna-4.5.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from rl_zoo3==2.7.0) (6.0.3)
# Collecting pytablewriter~=1.2 (from rl_zoo3==2.7.0)
#   Downloading pytablewriter-1.2.1-py3-none-any.whl.metadata (38 kB)
# Collecting shimmy~=2.0 (from rl_zoo3==2.7.0)
#   Downloading Shimmy-2.0.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium<1.3.0,>=0.29.1->rl_zoo3==2.7.0) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium<1.3.0,>=0.29.1->rl_zoo3==2.7.0) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium<1.3.0,>=0.29.1->rl_zoo3==2.7.0) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium<1.3.0,>=0.29.1->rl_zoo3==2.7.0) (0.0.4)
# Requirement already satisfied: huggingface-hub~=0.8 in /usr/local/lib/python3.12/dist-packages (from huggingface_sb3<4.0,>=3.0->rl_zoo3==2.7.0) (0.35.3)
# Requirement already satisfied: wasabi in /usr/local/lib/python3.12/dist-packages (from huggingface_sb3<4.0,>=3.0->rl_zoo3==2.7.0) (1.1.3)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.0->rl_zoo3==2.7.0) (1.16.5)
# Collecting colorlog (from optuna>=3.0->rl_zoo3==2.7.0)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.0->rl_zoo3==2.7.0) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.0->rl_zoo3==2.7.0) (2.0.43)
# Requirement already satisfied: setuptools>=38.3.0 in /usr/local/lib/python3.12/dist-packages (from pytablewriter~=1.2->rl_zoo3==2.7.0) (75.2.0)
# Collecting DataProperty<2,>=1.1.0 (from pytablewriter~=1.2->rl_zoo3==2.7.0)
#   Downloading DataProperty-1.1.0-py3-none-any.whl.metadata (11 kB)
# Collecting mbstrdecoder<2,>=1.0.0 (from pytablewriter~=1.2->rl_zoo3==2.7.0)
#   Downloading mbstrdecoder-1.1.4-py3-none-any.whl.metadata (4.3 kB)
# Collecting pathvalidate<4,>=2.3.0 (from pytablewriter~=1.2->rl_zoo3==2.7.0)
#   Downloading pathvalidate-3.3.1-py3-none-any.whl.metadata (12 kB)
# Collecting tabledata<2,>=1.3.1 (from pytablewriter~=1.2->rl_zoo3==2.7.0)
#   Downloading tabledata-1.3.4-py3-none-any.whl.metadata (3.7 kB)
# Collecting tcolorpy<1,>=0.0.5 (from pytablewriter~=1.2->rl_zoo3==2.7.0)
#   Downloading tcolorpy-0.1.7-py3-none-any.whl.metadata (6.3 kB)
# Collecting typepy<2,>=1.3.2 (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.7.0)
#   Downloading typepy-1.3.4-py3-none-any.whl.metadata (9.2 kB)
# Collecting stable_baselines3<3.0,>=2.7.0 (from sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0)
#   Downloading stable_baselines3-2.7.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->rl_zoo3==2.7.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->rl_zoo3==2.7.0) (2.19.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna>=3.0->rl_zoo3==2.7.0) (1.3.10)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.7.0) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.7.0) (2025.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.7.0) (2.32.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.7.0) (1.1.10)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->rl_zoo3==2.7.0) (0.1.2)
# Requirement already satisfied: chardet<6,>=3.0.4 in /usr/local/lib/python3.12/dist-packages (from mbstrdecoder<2,>=1.0.0->pytablewriter~=1.2->rl_zoo3==2.7.0) (5.2.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna>=3.0->rl_zoo3==2.7.0) (3.2.4)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.12/dist-packages (from stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (2.8.0+cu126)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (3.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.7.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2018.9 in /usr/local/lib/python3.12/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.7.0) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.8.0->typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.7.0) (1.17.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (3.4.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna>=3.0->rl_zoo3==2.7.0) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (3.2.5)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.7.0) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.7.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.7.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.7.0) (2025.10.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3_contrib<3.0,>=2.7.0->rl_zoo3==2.7.0) (1.3.0)
# Downloading huggingface_sb3-3.0-py3-none-any.whl (9.7 kB)
# Downloading optuna-4.5.0-py3-none-any.whl (400 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.9/400.9 kB 34.2 MB/s eta 0:00:00
# Downloading pytablewriter-1.2.1-py3-none-any.whl (91 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 9.4 MB/s eta 0:00:00
# Downloading sb3_contrib-2.7.0-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 10.2 MB/s eta 0:00:00
# Downloading Shimmy-2.0.0-py3-none-any.whl (30 kB)
# Downloading DataProperty-1.1.0-py3-none-any.whl (27 kB)
# Downloading mbstrdecoder-1.1.4-py3-none-any.whl (7.9 kB)
# Downloading pathvalidate-3.3.1-py3-none-any.whl (24 kB)
# Downloading stable_baselines3-2.7.0-py3-none-any.whl (187 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.2/187.2 kB 20.2 MB/s eta 0:00:00
# Downloading tabledata-1.3.4-py3-none-any.whl (11 kB)
# Downloading tcolorpy-0.1.7-py3-none-any.whl (8.1 kB)
# Downloading typepy-1.3.4-py3-none-any.whl (31 kB)
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Building wheels for collected packages: rl_zoo3
#   Building wheel for rl_zoo3 (pyproject.toml) ... done
#   Created wheel for rl_zoo3: filename=rl_zoo3-2.7.0-py3-none-any.whl size=78020 sha256=e8269dc68ada1a34a4f3ddeeec8897ef5f0e6bf17800d01090e1c5522081a9cd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-zcavez61/wheels/cd/09/5b/8130538724a187021e02afe53ce7a1269c516a78a487a1ba15
# Successfully built rl_zoo3
# Installing collected packages: tcolorpy, pathvalidate, mbstrdecoder, colorlog, typepy, shimmy, optuna, huggingface_sb3, stable_baselines3, DataProperty, tabledata, sb3_contrib, pytablewriter, rl_zoo3
# Successfully installed DataProperty-1.1.0 colorlog-6.9.0 huggingface_sb3-3.0 mbstrdecoder-1.1.4 optuna-4.5.0 pathvalidate-3.3.1 pytablewriter-1.2.1 rl_zoo3-2.7.0 sb3_contrib-2.7.0 shimmy-2.0.0 stable_baselines3-2.7.0 tabledata-1.3.4 tcolorpy-0.1.7 typepy-1.3.4

# %%
# !apt-get install swig cmake ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.2).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# The following additional packages will be installed:
#   swig4.0
# Suggested packages:
#   swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   swig swig4.0
# 0 upgraded, 2 newly installed, 0 to remove and 38 not upgraded.
# Need to get 1,116 kB of archives.
# After this operation, 5,542 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig4.0 amd64 4.0.2-1ubuntu1 [1,110 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig all 4.0.2-1ubuntu1 [5,632 B]
# Fetched 1,116 kB in 2s (519 kB/s)
# Selecting previously unselected package swig4.0.
# (Reading database ... 126675 files and directories currently installed.)
# Preparing to unpack .../swig4.0_4.0.2-1ubuntu1_amd64.deb ...
# Unpacking swig4.0 (4.0.2-1ubuntu1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_4.0.2-1ubuntu1_all.deb ...
# Unpacking swig (4.0.2-1ubuntu1) ...
# Setting up swig4.0 (4.0.2-1ubuntu1) ...
# Setting up swig (4.0.2-1ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %% [markdown]
# To be able to use Atari games in Gymnasium we need to install atari package. And accept-rom-license to download the rom files (games files).

# %%
# !pip install gymnasium[atari]
# !pip install gymnasium[accept-rom-license]
# Out:
# Requirement already satisfied: gymnasium[atari] in /usr/local/lib/python3.12/dist-packages (1.2.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (0.0.4)
# Requirement already satisfied: ale_py>=0.9 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (0.11.2)
# Requirement already satisfied: gymnasium[accept-rom-license] in /usr/local/lib/python3.12/dist-packages (1.2.1)
# WARNING: gymnasium 1.2.1 does not provide the extra 'accept-rom-license'
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[accept-rom-license]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[accept-rom-license]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[accept-rom-license]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[accept-rom-license]) (0.0.4)

# %% [markdown]
# ## Create a virtual display 🔽
#
# During the notebook, we'll need to generate a replay video. To do so, with colab, **we need to have a virtual screen to be able to render the environment** (and thus record the frames).
#
# Hence the following cell will install the librairies and create and run a virtual screen 🖥

# %%
# %%capture
# !apt install python-opengl
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %% [markdown]
# ## Train our Deep Q-Learning Agent to Play Space Invaders 👾
#
# To train an agent with RL-Baselines3-Zoo, we just need to do two things:
#
# 1. Create a hyperparameter config file that will contain our training hyperparameters called `dqn.yml`.
#
# This is a template example:
#
# ```
# SpaceInvadersNoFrameskip-v4:
#   env_wrapper:
#     - stable_baselines3.common.atari_wrappers.AtariWrapper
#   frame_stack: 4
#   policy: 'CnnPolicy'
#   n_timesteps: !!float 1e6
#   buffer_size: 100000
#   learning_rate: !!float 1e-4
#   batch_size: 32
#   learning_starts: 100000
#   target_update_interval: 1000
#   train_freq: 4
#   gradient_steps: 1
#   exploration_fraction: 0.1
#   exploration_final_eps: 0.01
#   # If True, you need to deactivate handle_timeout_termination
#   # in the replay_buffer_kwargs
#   optimize_memory_usage: False
# ```

# %% [markdown]
# Here we see that:
# - We use the `Atari Wrapper` that preprocess the input (Frame reduction ,grayscale, stack 4 frames)
# - We use `CnnPolicy`, since we use Convolutional layers to process the frames
# - We train it for 10 million `n_timesteps`
# - Memory (Experience Replay) size is 100000, aka the amount of experience steps you saved to train again your agent with.
#
# 💡 My advice is to **reduce the training timesteps to 1M,** which will take about 90 minutes on a P100. `!nvidia-smi` will tell you what GPU you're using. At 10 million steps, this will take about 9 hours, which could likely result in Colab timing out. I recommend running this on your local computer (or somewhere else). Just click on: `File>Download`.

# %% [markdown]
# In terms of hyperparameters optimization, my advice is to focus on these 3 hyperparameters:
# - `learning_rate`
# - `buffer_size (Experience Memory size)`
# - `batch_size`
#
# As a good practice, you need to **check the documentation to understand what each hyperparameters does**: https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html#parameters

# %% [markdown]
# 2. We start the training and save the models on `logs` folder 📁
#
# - Define the algorithm after `--algo`, where we save the model after `-f` and where the hyperparameter config is after `-c`.

# %%
# !python -m rl_zoo3.train --algo ________ --env SpaceInvadersNoFrameskip-v4  -f _________  -c _________

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.train --algo dqn  --env SpaceInvadersNoFrameskip-v4 -f logs/ -c dqn.yml
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# |    ep_rew_mean      | 292      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1932     |
# |    fps              | 262      |
# |    time_elapsed     | 1461     |
# |    total_timesteps  | 384413   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0244   |
# |    n_updates        | 93603    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.35e+03 |
# |    ep_rew_mean      | 291      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1936     |
# |    fps              | 263      |
# |    time_elapsed     | 1463     |
# |    total_timesteps  | 385059   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00842  |
# |    n_updates        | 93764    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.35e+03 |
# |    ep_rew_mean      | 290      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1940     |
# |    fps              | 262      |
# |    time_elapsed     | 1468     |
# |    total_timesteps  | 386112   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0178   |
# |    n_updates        | 94027    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.36e+03 |
# |    ep_rew_mean      | 290      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1944     |
# |    fps              | 263      |
# |    time_elapsed     | 1472     |
# |    total_timesteps  | 387300   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0108   |
# |    n_updates        | 94324    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.37e+03 |
# |    ep_rew_mean      | 290      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1948     |
# |    fps              | 263      |
# |    time_elapsed     | 1475     |
# |    total_timesteps  | 388230   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0156   |
# |    n_updates        | 94557    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.36e+03 |
# |    ep_rew_mean      | 289      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1952     |
# |    fps              | 263      |
# |    time_elapsed     | 1478     |
# |    total_timesteps  | 388975   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.123    |
# |    n_updates        | 94743    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.35e+03 |
# |    ep_rew_mean      | 292      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1956     |
# |    fps              | 263      |
# |    time_elapsed     | 1482     |
# |    total_timesteps  | 390024   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.014    |
# |    n_updates        | 95005    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.36e+03 |
# |    ep_rew_mean      | 294      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1960     |
# |    fps              | 263      |
# |    time_elapsed     | 1485     |
# |    total_timesteps  | 390751   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0128   |
# |    n_updates        | 95187    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.35e+03 |
# |    ep_rew_mean      | 292      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1964     |
# |    fps              | 263      |
# |    time_elapsed     | 1487     |
# |    total_timesteps  | 391457   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0345   |
# |    n_updates        | 95364    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.34e+03 |
# |    ep_rew_mean      | 285      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1968     |
# |    fps              | 263      |
# |    time_elapsed     | 1489     |
# |    total_timesteps  | 391946   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0124   |
# |    n_updates        | 95486    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.34e+03 |
# |    ep_rew_mean      | 286      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1972     |
# |    fps              | 263      |
# |    time_elapsed     | 1492     |
# |    total_timesteps  | 392775   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0157   |
# |    n_updates        | 95693    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.34e+03 |
# |    ep_rew_mean      | 286      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1976     |
# |    fps              | 263      |
# |    time_elapsed     | 1495     |
# |    total_timesteps  | 393415   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0138   |
# |    n_updates        | 95853    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.35e+03 |
# |    ep_rew_mean      | 288      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1980     |
# |    fps              | 263      |
# |    time_elapsed     | 1498     |
# |    total_timesteps  | 394280   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0106   |
# |    n_updates        | 96069    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.36e+03 |
# |    ep_rew_mean      | 289      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1984     |
# |    fps              | 263      |
# |    time_elapsed     | 1502     |
# |    total_timesteps  | 395308   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00818  |
# |    n_updates        | 96326    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.36e+03 |
# |    ep_rew_mean      | 288      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1988     |
# |    fps              | 263      |
# |    time_elapsed     | 1506     |
# |    total_timesteps  | 396501   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0185   |
# |    n_updates        | 96625    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.36e+03 |
# |    ep_rew_mean      | 287      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1992     |
# |    fps              | 263      |
# |    time_elapsed     | 1510     |
# |    total_timesteps  | 397435   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0293   |
# |    n_updates        | 96858    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.39e+03 |
# |    ep_rew_mean      | 292      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1996     |
# |    fps              | 263      |
# |    time_elapsed     | 1513     |
# |    total_timesteps  | 398400   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0174   |
# |    n_updates        | 97099    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.39e+03 |
# |    ep_rew_mean      | 291      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2000     |
# |    fps              | 263      |
# |    time_elapsed     | 1518     |
# |    total_timesteps  | 399531   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0184   |
# |    n_updates        | 97382    |
# ----------------------------------
# Eval num_timesteps=400000, episode_reward=283.00 +/- 28.57
# Episode length: 2681.00 +/- 137.94
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.68e+03 |
# |    mean_reward      | 283      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 400000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00598  |
# |    n_updates        | 97499    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.4e+03  |
# |    ep_rew_mean      | 292      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2004     |
# |    fps              | 261      |
# |    time_elapsed     | 1528     |
# |    total_timesteps  | 400546   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0198   |
# |    n_updates        | 97636    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.41e+03 |
# |    ep_rew_mean      | 292      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2008     |
# |    fps              | 261      |
# |    time_elapsed     | 1531     |
# |    total_timesteps  | 401360   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0082   |
# |    n_updates        | 97839    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.39e+03 |
# |    ep_rew_mean      | 286      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2012     |
# |    fps              | 262      |
# |    time_elapsed     | 1534     |
# |    total_timesteps  | 402180   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0291   |
# |    n_updates        | 98044    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.38e+03 |
# |    ep_rew_mean      | 284      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2016     |
# |    fps              | 261      |
# |    time_elapsed     | 1538     |
# |    total_timesteps  | 403083   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0264   |
# |    n_updates        | 98270    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.39e+03 |
# |    ep_rew_mean      | 286      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2020     |
# |    fps              | 262      |
# |    time_elapsed     | 1541     |
# |    total_timesteps  | 403831   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0222   |
# |    n_updates        | 98457    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.38e+03 |
# |    ep_rew_mean      | 285      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2024     |
# |    fps              | 262      |
# |    time_elapsed     | 1543     |
# |    total_timesteps  | 404553   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00649  |
# |    n_updates        | 98638    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.41e+03 |
# |    ep_rew_mean      | 288      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2028     |
# |    fps              | 262      |
# |    time_elapsed     | 1547     |
# |    total_timesteps  | 405444   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0153   |
# |    n_updates        | 98860    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.42e+03 |
# |    ep_rew_mean      | 290      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2032     |
# |    fps              | 262      |
# |    time_elapsed     | 1549     |
# |    total_timesteps  | 406091   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0697   |
# |    n_updates        | 99022    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.42e+03 |
# |    ep_rew_mean      | 290      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2036     |
# |    fps              | 262      |
# |    time_elapsed     | 1553     |
# |    total_timesteps  | 407048   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0789   |
# |    n_updates        | 99261    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.43e+03 |
# |    ep_rew_mean      | 292      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2040     |
# |    fps              | 262      |
# |    time_elapsed     | 1556     |
# |    total_timesteps  | 407878   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0163   |
# |    n_updates        | 99469    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.44e+03 |
# |    ep_rew_mean      | 293      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2044     |
# |    fps              | 262      |
# |    time_elapsed     | 1559     |
# |    total_timesteps  | 408820   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0287   |
# |    n_updates        | 99704    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.45e+03 |
# |    ep_rew_mean      | 294      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2048     |
# |    fps              | 262      |
# |    time_elapsed     | 1563     |
# |    total_timesteps  | 409663   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0139   |
# |    n_updates        | 99915    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.45e+03 |
# |    ep_rew_mean      | 293      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2052     |
# |    fps              | 262      |
# |    time_elapsed     | 1565     |
# |    total_timesteps  | 410164   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0137   |
# |    n_updates        | 100040   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.46e+03 |
# |    ep_rew_mean      | 295      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2056     |
# |    fps              | 262      |
# |    time_elapsed     | 1568     |
# |    total_timesteps  | 411207   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0211   |
# |    n_updates        | 100301   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.47e+03 |
# |    ep_rew_mean      | 298      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2060     |
# |    fps              | 262      |
# |    time_elapsed     | 1571     |
# |    total_timesteps  | 411933   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00916  |
# |    n_updates        | 100483   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.49e+03 |
# |    ep_rew_mean      | 300      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2064     |
# |    fps              | 262      |
# |    time_elapsed     | 1574     |
# |    total_timesteps  | 412648   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0173   |
# |    n_updates        | 100661   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.49e+03 |
# |    ep_rew_mean      | 300      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2068     |
# |    fps              | 262      |
# |    time_elapsed     | 1577     |
# |    total_timesteps  | 413353   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.013    |
# |    n_updates        | 100838   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.5e+03  |
# |    ep_rew_mean      | 301      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2072     |
# |    fps              | 262      |
# |    time_elapsed     | 1580     |
# |    total_timesteps  | 414384   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00695  |
# |    n_updates        | 101095   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.51e+03 |
# |    ep_rew_mean      | 303      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2076     |
# |    fps              | 262      |
# |    time_elapsed     | 1583     |
# |    total_timesteps  | 415194   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0111   |
# |    n_updates        | 101298   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.5e+03  |
# |    ep_rew_mean      | 301      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2080     |
# |    fps              | 262      |
# |    time_elapsed     | 1587     |
# |    total_timesteps  | 416049   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0123   |
# |    n_updates        | 101512   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.5e+03  |
# |    ep_rew_mean      | 299      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2084     |
# |    fps              | 262      |
# |    time_elapsed     | 1591     |
# |    total_timesteps  | 417141   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0136   |
# |    n_updates        | 101785   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.51e+03 |
# |    ep_rew_mean      | 302      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2088     |
# |    fps              | 262      |
# |    time_elapsed     | 1593     |
# |    total_timesteps  | 417757   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.023    |
# |    n_updates        | 101939   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.51e+03 |
# |    ep_rew_mean      | 303      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2092     |
# |    fps              | 262      |
# |    time_elapsed     | 1596     |
# |    total_timesteps  | 418566   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0214   |
# |    n_updates        | 102141   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.51e+03 |
# |    ep_rew_mean      | 303      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2096     |
# |    fps              | 262      |
# |    time_elapsed     | 1600     |
# |    total_timesteps  | 419603   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0208   |
# |    n_updates        | 102400   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.55e+03 |
# |    ep_rew_mean      | 308      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2100     |
# |    fps              | 262      |
# |    time_elapsed     | 1604     |
# |    total_timesteps  | 420841   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0194   |
# |    n_updates        | 102710   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.55e+03 |
# |    ep_rew_mean      | 308      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2104     |
# |    fps              | 262      |
# |    time_elapsed     | 1608     |
# |    total_timesteps  | 421877   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0127   |
# |    n_updates        | 102969   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.57e+03 |
# |    ep_rew_mean      | 307      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2108     |
# |    fps              | 262      |
# |    time_elapsed     | 1613     |
# |    total_timesteps  | 423095   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0518   |
# |    n_updates        | 103273   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.58e+03 |
# |    ep_rew_mean      | 310      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2112     |
# |    fps              | 262      |
# |    time_elapsed     | 1616     |
# |    total_timesteps  | 423997   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0142   |
# |    n_updates        | 103499   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.59e+03 |
# |    ep_rew_mean      | 311      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2116     |
# |    fps              | 262      |
# |    time_elapsed     | 1618     |
# |    total_timesteps  | 424582   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0156   |
# |    n_updates        | 103645   |
# ----------------------------------
# Eval num_timesteps=425000, episode_reward=465.00 +/- 220.30
# Episode length: 2680.20 +/- 498.75
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.68e+03 |
# |    mean_reward      | 465      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 425000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0198   |
# |    n_updates        | 103749   |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.58e+03 |
# |    ep_rew_mean      | 311      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2120     |
# |    fps              | 261      |
# |    time_elapsed     | 1629     |
# |    total_timesteps  | 425547   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.011    |
# |    n_updates        | 103886   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.59e+03 |
# |    ep_rew_mean      | 313      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2124     |
# |    fps              | 261      |
# |    time_elapsed     | 1632     |
# |    total_timesteps  | 426417   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0086   |
# |    n_updates        | 104104   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.6e+03  |
# |    ep_rew_mean      | 314      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2128     |
# |    fps              | 261      |
# |    time_elapsed     | 1635     |
# |    total_timesteps  | 427099   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0221   |
# |    n_updates        | 104274   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.61e+03 |
# |    ep_rew_mean      | 313      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2132     |
# |    fps              | 261      |
# |    time_elapsed     | 1638     |
# |    total_timesteps  | 427976   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0133   |
# |    n_updates        | 104493   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.62e+03 |
# |    ep_rew_mean      | 316      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2136     |
# |    fps              | 261      |
# |    time_elapsed     | 1641     |
# |    total_timesteps  | 428854   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0526   |
# |    n_updates        | 104713   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.62e+03 |
# |    ep_rew_mean      | 317      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2140     |
# |    fps              | 261      |
# |    time_elapsed     | 1643     |
# |    total_timesteps  | 429377   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0216   |
# |    n_updates        | 104844   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.6e+03  |
# |    ep_rew_mean      | 315      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2144     |
# |    fps              | 261      |
# |    time_elapsed     | 1647     |
# |    total_timesteps  | 430287   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0102   |
# |    n_updates        | 105071   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.6e+03  |
# |    ep_rew_mean      | 315      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2148     |
# |    fps              | 261      |
# |    time_elapsed     | 1649     |
# |    total_timesteps  | 431059   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0217   |
# |    n_updates        | 105264   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.59e+03 |
# |    ep_rew_mean      | 314      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2152     |
# |    fps              | 261      |
# |    time_elapsed     | 1652     |
# |    total_timesteps  | 431713   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.018    |
# |    n_updates        | 105428   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.6e+03  |
# |    ep_rew_mean      | 315      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2156     |
# |    fps              | 261      |
# |    time_elapsed     | 1657     |
# |    total_timesteps  | 432822   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00654  |
# |    n_updates        | 105705   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.62e+03 |
# |    ep_rew_mean      | 318      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2160     |
# |    fps              | 261      |
# |    time_elapsed     | 1660     |
# |    total_timesteps  | 433945   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0138   |
# |    n_updates        | 105986   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.6e+03  |
# |    ep_rew_mean      | 316      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2164     |
# |    fps              | 261      |
# |    time_elapsed     | 1663     |
# |    total_timesteps  | 434755   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0215   |
# |    n_updates        | 106188   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.6e+03  |
# |    ep_rew_mean      | 315      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2168     |
# |    fps              | 261      |
# |    time_elapsed     | 1666     |
# |    total_timesteps  | 435526   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00992  |
# |    n_updates        | 106381   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.59e+03 |
# |    ep_rew_mean      | 315      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2172     |
# |    fps              | 261      |
# |    time_elapsed     | 1669     |
# |    total_timesteps  | 436260   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00933  |
# |    n_updates        | 106564   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.57e+03 |
# |    ep_rew_mean      | 310      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2176     |
# |    fps              | 261      |
# |    time_elapsed     | 1671     |
# |    total_timesteps  | 436835   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0165   |
# |    n_updates        | 106708   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.57e+03 |
# |    ep_rew_mean      | 313      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2180     |
# |    fps              | 261      |
# |    time_elapsed     | 1674     |
# |    total_timesteps  | 437641   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0124   |
# |    n_updates        | 106910   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.56e+03 |
# |    ep_rew_mean      | 312      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2184     |
# |    fps              | 261      |
# |    time_elapsed     | 1677     |
# |    total_timesteps  | 438540   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0478   |
# |    n_updates        | 107134   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.57e+03 |
# |    ep_rew_mean      | 314      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2188     |
# |    fps              | 261      |
# |    time_elapsed     | 1681     |
# |    total_timesteps  | 439486   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0345   |
# |    n_updates        | 107371   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.57e+03 |
# |    ep_rew_mean      | 313      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2192     |
# |    fps              | 261      |
# |    time_elapsed     | 1684     |
# |    total_timesteps  | 440429   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.02     |
# |    n_updates        | 107607   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.57e+03 |
# |    ep_rew_mean      | 313      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2196     |
# |    fps              | 261      |
# |    time_elapsed     | 1688     |
# |    total_timesteps  | 441360   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0159   |
# |    n_updates        | 107839   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.58e+03 |
# |    ep_rew_mean      | 315      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2200     |
# |    fps              | 261      |
# |    time_elapsed     | 1690     |
# |    total_timesteps  | 442048   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00889  |
# |    n_updates        | 108011   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.58e+03 |
# |    ep_rew_mean      | 317      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2204     |
# |    fps              | 261      |
# |    time_elapsed     | 1694     |
# |    total_timesteps  | 443071   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0225   |
# |    n_updates        | 108267   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.59e+03 |
# |    ep_rew_mean      | 318      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2208     |
# |    fps              | 261      |
# |    time_elapsed     | 1697     |
# |    total_timesteps  | 444022   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0157   |
# |    n_updates        | 108505   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.59e+03 |
# |    ep_rew_mean      | 319      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2212     |
# |    fps              | 261      |
# |    time_elapsed     | 1700     |
# |    total_timesteps  | 444826   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0127   |
# |    n_updates        | 108706   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.61e+03 |
# |    ep_rew_mean      | 320      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2216     |
# |    fps              | 261      |
# |    time_elapsed     | 1704     |
# |    total_timesteps  | 445807   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00854  |
# |    n_updates        | 108951   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.58e+03 |
# |    ep_rew_mean      | 317      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2220     |
# |    fps              | 261      |
# |    time_elapsed     | 1706     |
# |    total_timesteps  | 446350   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0135   |
# |    n_updates        | 109087   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.57e+03 |
# |    ep_rew_mean      | 316      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2224     |
# |    fps              | 261      |
# |    time_elapsed     | 1709     |
# |    total_timesteps  | 447085   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00973  |
# |    n_updates        | 109271   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.56e+03 |
# |    ep_rew_mean      | 313      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2228     |
# |    fps              | 261      |
# |    time_elapsed     | 1711     |
# |    total_timesteps  | 447693   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0106   |
# |    n_updates        | 109423   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.57e+03 |
# |    ep_rew_mean      | 314      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2232     |
# |    fps              | 261      |
# |    time_elapsed     | 1713     |
# |    total_timesteps  | 448369   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0111   |
# |    n_updates        | 109592   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.55e+03 |
# |    ep_rew_mean      | 312      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2236     |
# |    fps              | 261      |
# |    time_elapsed     | 1716     |
# |    total_timesteps  | 449066   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0382   |
# |    n_updates        | 109766   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.54e+03 |
# |    ep_rew_mean      | 310      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2240     |
# |    fps              | 261      |
# |    time_elapsed     | 1719     |
# |    total_timesteps  | 449916   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0118   |
# |    n_updates        | 109978   |
# ----------------------------------
# Eval num_timesteps=450000, episode_reward=331.00 +/- 116.08
# Episode length: 2155.00 +/- 627.43
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.16e+03 |
# |    mean_reward      | 331      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 450000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.118    |
# |    n_updates        | 109999   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.53e+03 |
# |    ep_rew_mean      | 310      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2244     |
# |    fps              | 260      |
# |    time_elapsed     | 1728     |
# |    total_timesteps  | 450619   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00909  |
# |    n_updates        | 110154   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.52e+03 |
# |    ep_rew_mean      | 307      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2248     |
# |    fps              | 260      |
# |    time_elapsed     | 1730     |
# |    total_timesteps  | 451277   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0127   |
# |    n_updates        | 110319   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.52e+03 |
# |    ep_rew_mean      | 306      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2252     |
# |    fps              | 260      |
# |    time_elapsed     | 1733     |
# |    total_timesteps  | 452190   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0295   |
# |    n_updates        | 110547   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.53e+03 |
# |    ep_rew_mean      | 309      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2256     |
# |    fps              | 260      |
# |    time_elapsed     | 1737     |
# |    total_timesteps  | 453324   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.011    |
# |    n_updates        | 110830   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.54e+03 |
# |    ep_rew_mean      | 311      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2260     |
# |    fps              | 260      |
# |    time_elapsed     | 1740     |
# |    total_timesteps  | 454083   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0131   |
# |    n_updates        | 111020   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.55e+03 |
# |    ep_rew_mean      | 313      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2264     |
# |    fps              | 260      |
# |    time_elapsed     | 1743     |
# |    total_timesteps  | 454824   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0962   |
# |    n_updates        | 111205   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.54e+03 |
# |    ep_rew_mean      | 310      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2268     |
# |    fps              | 260      |
# |    time_elapsed     | 1746     |
# |    total_timesteps  | 455614   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0135   |
# |    n_updates        | 111403   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.55e+03 |
# |    ep_rew_mean      | 312      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2272     |
# |    fps              | 260      |
# |    time_elapsed     | 1749     |
# |    total_timesteps  | 456366   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0312   |
# |    n_updates        | 111591   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.55e+03 |
# |    ep_rew_mean      | 310      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2276     |
# |    fps              | 260      |
# |    time_elapsed     | 1752     |
# |    total_timesteps  | 457170   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00806  |
# |    n_updates        | 111792   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.53e+03 |
# |    ep_rew_mean      | 307      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2280     |
# |    fps              | 260      |
# |    time_elapsed     | 1754     |
# |    total_timesteps  | 457763   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0194   |
# |    n_updates        | 111940   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.52e+03 |
# |    ep_rew_mean      | 306      |
# |    exploration_rate | 0.01     |
# ...
# | rollout/            |          |
# |    ep_len_mean      | 2.56e+03 |
# |    ep_rew_mean      | 316      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3108     |
# |    fps              | 257      |
# |    time_elapsed     | 2431     |
# |    total_timesteps  | 626326   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0215   |
# |    n_updates        | 154081   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.56e+03 |
# |    ep_rew_mean      | 319      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3112     |
# |    fps              | 257      |
# |    time_elapsed     | 2433     |
# |    total_timesteps  | 626895   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00954  |
# |    n_updates        | 154223   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.54e+03 |
# |    ep_rew_mean      | 315      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3116     |
# |    fps              | 257      |
# |    time_elapsed     | 2436     |
# |    total_timesteps  | 627719   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0132   |
# |    n_updates        | 154429   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.55e+03 |
# |    ep_rew_mean      | 317      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3120     |
# |    fps              | 257      |
# |    time_elapsed     | 2439     |
# |    total_timesteps  | 628598   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0107   |
# |    n_updates        | 154649   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.55e+03 |
# |    ep_rew_mean      | 319      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3124     |
# |    fps              | 257      |
# |    time_elapsed     | 2442     |
# |    total_timesteps  | 629395   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00901  |
# |    n_updates        | 154848   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.54e+03 |
# |    ep_rew_mean      | 316      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3128     |
# |    fps              | 257      |
# |    time_elapsed     | 2445     |
# |    total_timesteps  | 630207   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00906  |
# |    n_updates        | 155051   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.54e+03 |
# |    ep_rew_mean      | 317      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3132     |
# |    fps              | 257      |
# |    time_elapsed     | 2449     |
# |    total_timesteps  | 631277   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0135   |
# |    n_updates        | 155319   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.55e+03 |
# |    ep_rew_mean      | 319      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3136     |
# |    fps              | 257      |
# |    time_elapsed     | 2452     |
# |    total_timesteps  | 632146   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0173   |
# |    n_updates        | 155536   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.53e+03 |
# |    ep_rew_mean      | 317      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3140     |
# |    fps              | 257      |
# |    time_elapsed     | 2456     |
# |    total_timesteps  | 633113   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0118   |
# |    n_updates        | 155778   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.53e+03 |
# |    ep_rew_mean      | 317      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3144     |
# |    fps              | 257      |
# |    time_elapsed     | 2459     |
# |    total_timesteps  | 633848   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00753  |
# |    n_updates        | 155961   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.53e+03 |
# |    ep_rew_mean      | 317      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3148     |
# |    fps              | 257      |
# |    time_elapsed     | 2461     |
# |    total_timesteps  | 634603   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00595  |
# |    n_updates        | 156150   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.53e+03 |
# |    ep_rew_mean      | 319      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3152     |
# |    fps              | 257      |
# |    time_elapsed     | 2464     |
# |    total_timesteps  | 635333   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0301   |
# |    n_updates        | 156333   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.54e+03 |
# |    ep_rew_mean      | 319      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3156     |
# |    fps              | 257      |
# |    time_elapsed     | 2468     |
# |    total_timesteps  | 636328   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0155   |
# |    n_updates        | 156581   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.53e+03 |
# |    ep_rew_mean      | 317      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3160     |
# |    fps              | 257      |
# |    time_elapsed     | 2470     |
# |    total_timesteps  | 637011   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0346   |
# |    n_updates        | 156752   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.55e+03 |
# |    ep_rew_mean      | 320      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3164     |
# |    fps              | 257      |
# |    time_elapsed     | 2474     |
# |    total_timesteps  | 638081   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0145   |
# |    n_updates        | 157020   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.55e+03 |
# |    ep_rew_mean      | 321      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3168     |
# |    fps              | 257      |
# |    time_elapsed     | 2478     |
# |    total_timesteps  | 639124   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00799  |
# |    n_updates        | 157280   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.55e+03 |
# |    ep_rew_mean      | 321      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3172     |
# |    fps              | 257      |
# |    time_elapsed     | 2482     |
# |    total_timesteps  | 640186   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0255   |
# |    n_updates        | 157546   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.57e+03 |
# |    ep_rew_mean      | 326      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3176     |
# |    fps              | 257      |
# |    time_elapsed     | 2486     |
# |    total_timesteps  | 641391   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0328   |
# |    n_updates        | 157847   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.57e+03 |
# |    ep_rew_mean      | 325      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3180     |
# |    fps              | 257      |
# |    time_elapsed     | 2489     |
# |    total_timesteps  | 642102   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0285   |
# |    n_updates        | 158025   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.57e+03 |
# |    ep_rew_mean      | 326      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3184     |
# |    fps              | 257      |
# |    time_elapsed     | 2492     |
# |    total_timesteps  | 643003   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0101   |
# |    n_updates        | 158250   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.58e+03 |
# |    ep_rew_mean      | 330      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3188     |
# |    fps              | 257      |
# |    time_elapsed     | 2496     |
# |    total_timesteps  | 643964   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.014    |
# |    n_updates        | 158490   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.58e+03 |
# |    ep_rew_mean      | 330      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3192     |
# |    fps              | 258      |
# |    time_elapsed     | 2499     |
# |    total_timesteps  | 644800   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0121   |
# |    n_updates        | 158699   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.57e+03 |
# |    ep_rew_mean      | 329      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3196     |
# |    fps              | 257      |
# |    time_elapsed     | 2502     |
# |    total_timesteps  | 645518   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0105   |
# |    n_updates        | 158879   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.55e+03 |
# |    ep_rew_mean      | 328      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3200     |
# |    fps              | 258      |
# |    time_elapsed     | 2505     |
# |    total_timesteps  | 646469   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.012    |
# |    n_updates        | 159117   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.56e+03 |
# |    ep_rew_mean      | 329      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3204     |
# |    fps              | 258      |
# |    time_elapsed     | 2508     |
# |    total_timesteps  | 647164   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0121   |
# |    n_updates        | 159290   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.57e+03 |
# |    ep_rew_mean      | 330      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3208     |
# |    fps              | 258      |
# |    time_elapsed     | 2511     |
# |    total_timesteps  | 648084   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0108   |
# |    n_updates        | 159520   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.58e+03 |
# |    ep_rew_mean      | 334      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3212     |
# |    fps              | 258      |
# |    time_elapsed     | 2515     |
# |    total_timesteps  | 649057   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00515  |
# |    n_updates        | 159764   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.57e+03 |
# |    ep_rew_mean      | 333      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3216     |
# |    fps              | 258      |
# |    time_elapsed     | 2518     |
# |    total_timesteps  | 649965   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00788  |
# |    n_updates        | 159991   |
# ----------------------------------
# Saving to logs//dqn/SpaceInvadersNoFrameskip-v4_1
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/usr/local/lib/python3.12/dist-packages/rl_zoo3/train.py", line 286, in <module>
#     train()
#   File "/usr/local/lib/python3.12/dist-packages/rl_zoo3/train.py", line 280, in train
#     exp_manager.save_trained_model(model)
#   File "/usr/local/lib/python3.12/dist-packages/rl_zoo3/exp_manager.py", line 286, in save_trained_model
#     model.save(f"{self.save_path}/{self.env_name}")
#   File "/usr/local/lib/python3.12/dist-packages/stable_baselines3/common/base_class.py", line 865, in save
#     params_to_save = self.get_parameters()
#                      ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/stable_baselines3/common/base_class.py", line 816, in get_parameters
#     params[name] = attr.state_dict()
#                    ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 2257, in state_dict
#     self._save_to_state_dict(destination, prefix, keep_vars)
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 2158, in _save_to_state_dict
#     getattr(self.__class__, "get_extra_state", Module.get_extra_state)
# KeyboardInterrupt

# %% [markdown]
# ## Let's evaluate our agent 👀
# - RL-Baselines3-Zoo provides `enjoy.py`, a python script to evaluate our agent. In most RL libraries, we call the evaluation script `enjoy.py`.
# - Let's evaluate it for 5000 timesteps 🔥

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps _________  --folder logs/

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000  --folder logs/
# Out:
# 2025-10-11 08:09:45.775963: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1760170185.795541   15661 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1760170185.801502   15661 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1760170185.817779   15661 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1760170185.817806   15661 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1760170185.817810   15661 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1760170185.817814   15661 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-10-11 08:09:45.822504: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Loading latest experiment, id=1
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_1/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Stacking 4 frames
# Atari Episode Score: 400.00
# Atari Episode Length 2409
# Atari Episode Score: 350.00
# Atari Episode Length 2457
# Atari Episode Score: 280.00
# Atari Episode Length 1983
# Atari Episode Score: 305.00
# Atari Episode Length 1989
# Atari Episode Score: 320.00
# Atari Episode Length 2201
# Atari Episode Score: 320.00
# Atari Episode Length 2201
# Atari Episode Score: 410.00
# Atari Episode Length 2699
# Atari Episode Score: 410.00
# Atari Episode Length 2759

# %% [markdown]
# ## Publish our trained model on the Hub 🚀
# Now that we saw we got good results after the training, we can publish our trained model on the hub 🤗 with one line of code.
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit3/space-invaders-model.gif" alt="Space Invaders model">

# %% [markdown]
# By using `rl_zoo3.push_to_hub` **you evaluate, record a replay, generate a model card of your agent and push it to the hub**.
#
# This way:
# - You can **showcase our work** 🔥
# - You can **visualize your agent playing** 👀
# - You can **share with the community an agent that others can use** 💾
# - You can **access a leaderboard 🏆 to see how well your agent is performing compared to your classmates** 👉  https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard

# %% [markdown]
# To be able to share your model with the community there are three more steps to follow:
#
# 1️⃣ (If it's not already done) create an account to HF ➡ https://huggingface.co/join
#
# 2️⃣ Sign in and then, you need to store your authentication token from the Hugging Face website.
# - Create a new token (https://huggingface.co/settings/tokens) **with write role**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/create-token.jpg" alt="Create HF Token">

# %% [markdown]
# - Copy the token
# - Run the cell below and past the token

# %%
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.
notebook_login()
# !git config --global credential.helper store
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# If you don't want to use a Google Colab or a Jupyter Notebook, you need to use this command instead: `huggingface-cli login`

# %% [markdown]
# 3️⃣ We're now ready to push our trained agent to the 🤗 Hub 🔥

# %% [markdown]
# Let's run push_to_hub.py file to upload our trained agent to the Hub.
#
# `--repo-name `: The name of the repo
#
# `-orga`: Your Hugging Face username
#
# `-f`: Where the trained model folder is (in our case `logs`)
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit3/select-id.png" alt="Select Id">

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name _____________________ -orga _____________________ -f logs/
# Out:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 189, in _run_module_as_main
#   File "<frozen runpy>", line 112, in _get_module_details
#   File "/usr/local/lib/python3.12/dist-packages/rl_zoo3/__init__.py", line 9, in <module>
#     from rl_zoo3.utils import (
#   File "/usr/local/lib/python3.12/dist-packages/rl_zoo3/utils.py", line 9, in <module>
#     import stable_baselines3 as sb3  # noqa: F401
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/stable_baselines3/__init__.py", line 3, in <module>
#     from stable_baselines3.a2c import A2C
#   File "/usr/local/lib/python3.12/dist-packages/stable_baselines3/a2c/__init__.py", line 1, in <module>
#     from stable_baselines3.a2c.a2c import A2C
#   File "/usr/local/lib/python3.12/dist-packages/stable_baselines3/a2c/a2c.py", line 3, in <module>
#     import torch as th
#   File "/usr/local/lib/python3.12/dist-packages/torch/__init__.py", line 2668, in <module>
#   File "/usr/local/lib/python3.12/dist-packages/torch/_meta_registrations.py", line 13, in <module>
#     from torch._decomp import (
#   File "/usr/local/lib/python3.12/dist-packages/torch/_decomp/__init__.py", line 276, in <module>
#     import torch._decomp.decompositions
#   File "/usr/local/lib/python3.12/dist-packages/torch/_decomp/decompositions.py", line 16, in <module>
#     import torch._prims as prims
#   File "/usr/local/lib/python3.12/dist-packages/torch/_prims/__init__.py", line 588, in <module>
#     bessel_j0 = _make_elementwise_unary_prim(
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/_prims/__init__.py", line 493, in _make_elementwise_unary_prim
#     return _make_prim(
#            ^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/_prims/__init__.py", line 321, in _make_prim
#     prim_def = torch.library.custom_op(
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/_library/custom_ops.py", line 174, in custom_op
#     return inner(fn)
#            ^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/_library/custom_ops.py", line 155, in inner
#     result = CustomOpDef(namespace, opname, schema_str, fn, tags)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/_library/custom_ops.py", line 213, in __init__
#     self._register_to_dispatcher(self._tags)
#   File "/usr/local/lib/python3.12/dist-packages/torch/_library/custom_ops.py", line 636, in _register_to_dispatcher
#     autograd_impl = autograd.make_autograd_impl(self._opoverload, self)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/_library/autograd.py", line 28, in make_autograd_impl
#     @dataclass
#      ^^^^^^^^^
#   File "/usr/lib/python3.12/dataclasses.py", line 1275, in dataclass
#     return wrap(cls)
#            ^^^^^^^^^
#   File "/usr/lib/python3.12/dataclasses.py", line 1265, in wrap
#     return _process_class(cls, init, repr, eq, order, unsafe_hash,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/dataclasses.py", line 1142, in _process_class
#     tuple(f.name for f in std_init_fields))
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/dataclasses.py", line 1142, in <genexpr>
#     tuple(f.name for f in std_init_fields))
#
# KeyboardInterrupt
# ^C

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name dqn-SpaceInvadersNoFrameskip-v4  -orga KeQingXiaoJieDeGou  -f logs/
# Out:
# 2025-10-11 08:10:12.981460: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1760170213.014930   15792 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1760170213.025247   15792 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1760170213.051263   15792 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1760170213.051307   15792 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1760170213.051314   15792 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1760170213.051322   15792 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-10-11 08:10:13.058803: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Loading latest experiment, id=1
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_1/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Uploading to KeQingXiaoJieDeGou/dqn-SpaceInvadersNoFrameskip-v4, make sure to have the rights
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to some
# minutes if video generation is activated. This is a work in progress: if you
# encounter a bug, please open an issue.
# Fetching 14 files:   0% 0/14 [00:00<?, ?it/s]
# _stable_baselines3_version: 100% 5.00/5.00 [00:00<00:00, 37.9kB/s]
#
# config.yml: 100% 547/547 [00:00<00:00, 4.20MB/s]
#
# README.md: 2.83kB [00:00, 6.73MB/s]
#
# args.yml: 1.27kB [00:00, 4.62MB/s]
#
# data: 205kB [00:00, 197MB/s]
#
# .gitattributes: 1.56kB [00:00, 6.26MB/s]
# Fetching 14 files:   7% 1/14 [00:02<00:29,  2.25s/it]
# system_info.txt: 100% 259/259 [00:00<00:00, 1.92MB/s]
# Fetching 14 files:  79% 11/14 [00:02<00:00,  5.92it/s]
# env_kwargs.yml: 100% 23.0/23.0 [00:00<00:00, 186kB/s]
#
# results.json: 100% 152/152 [00:00<00:00, 1.01MB/s]
# Fetching 14 files: 100% 14/14 [00:02<00:00,  4.96it/s]
# Saving model to: hub/dqn-SpaceInvadersNoFrameskip-v4/dqn-SpaceInvadersNoFrameskip-v4
# Saving video to /tmp/tmpbjyr19b0/-step-0-to-step-1000.mp4
# Moviepy - Building video /tmp/tmpbjyr19b0/-step-0-to-step-1000.mp4.
# Moviepy - Writing video /tmp/tmpbjyr19b0/-step-0-to-step-1000.mp4
#
# Moviepy - Done !
# Moviepy - video ready /tmp/tmpbjyr19b0/-step-0-to-step-1000.mp4
# ✘ 'DummyVecEnv' object has no attribute 'video_recorder'
# ✘ We are unable to generate a replay of your agent, the package_to_hub
# process continues
# ✘ Please open an issue at
# https://github.com/huggingface/huggingface_sb3/issues
# ℹ Pushing repo dqn-SpaceInvadersNoFrameskip-v4 to the Hugging Face
# Hub
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#
#   ...v4/train_eval_metrics.zip: 100% 28.6k/28.6k [00:00<?, ?B/s]
#
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:00<?, ?B/s]
#
#
#
#   ...p-v4/policy.optimizer.pth: 100% 13.5M/13.5M [00:00<?, ?B/s]
#
#
#
#
#   ...NoFrameskip-v4/policy.pth: 100% 13.5M/13.5M [00:00<?, ?B/s]
#
#   ...v4/train_eval_metrics.zip: 100% 28.6k/28.6k [00:00<?, ?B/s]
#
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:00<?, ?B/s]
#
#
#
#   ...p-v4/policy.optimizer.pth: 100% 13.5M/13.5M [00:00<?, ?B/s]
#
#
#
#
# Processing Files (4 / 4)      :  50% 27.0M/54.3M [00:00<00:00, 129MB/s,   ???B/s  ]
#
#   ...v4/train_eval_metrics.zip: 100% 28.6k/28.6k [00:00<?, ?B/s]
#
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:00<?, ?B/s]
#
#
#
#   ...p-v4/policy.optimizer.pth: 100% 13.5M/13.5M [00:00<?, ?B/s]
#
#
#
#
#   ...NoFrameskip-v4/policy.pth: 100% 13.5M/13.5M [00:00<?, ?B/s]
#
#   ...v4/train_eval_metrics.zip: 100% 28.6k/28.6k [00:00<?, ?B/s]
#
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:00<?, ?B/s]
#
#
#
#   ...p-v4/policy.optimizer.pth: 100% 13.5M/13.5M [00:00<?, ?B/s]
#
#
#
#
#   ...NoFrameskip-v4/policy.pth: 100% 13.5M/13.5M [00:00<?, ?B/s]
#
#   ...v4/train_eval_metrics.zip: 100% 28.6k/28.6k [00:00<?, ?B/s]
#
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:00<?, ?B/s]
#
#
#
#   ...p-v4/policy.optimizer.pth: 100% 13.5M/13.5M [00:00<?, ?B/s]
#
#
#
#
#   ...NoFrameskip-v4/policy.pth: 100% 13.5M/13.5M [00:00<?, ?B/s]
#
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip:  61% 16.5M/27.2M [00:00<?, ?B/s]
#
#   ...v4/train_eval_metrics.zip: 100% 28.6k/28.6k [00:00<?, ?B/s]
#
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:00<?, ?B/s]
#
#
#
#   ...p-v4/policy.optimizer.pth: 100% 13.5M/13.5M [00:00<?, ?B/s]
#
#
#
#
#   ...NoFrameskip-v4/policy.pth: 100% 13.5M/13.5M [00:00<?, ?B/s]
#
#
#
#
#
# Processing Files (4 / 5)      :  80% 43.5M/54.3M [00:01<00:00, 37.4MB/s, 20.6MB/s  ]
#
#   ...v4/train_eval_metrics.zip: 100% 28.6k/28.6k [00:01<?, ?B/s]
#
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:01<?, ?B/s]
#
#
#
#   ...p-v4/policy.optimizer.pth: 100% 13.5M/13.5M [00:01<?, ?B/s]
#
#
#
#
#   ...NoFrameskip-v4/policy.pth: 100% 13.5M/13.5M [00:01<?, ?B/s]
#
#
#
#
#
# Processing Files (4 / 5)      :  99% 54.0M/54.3M [00:01<00:00, 40.9MB/s, 26.9MB/s  ]
#
#   ...v4/train_eval_metrics.zip: 100% 28.6k/28.6k [00:01<?, ?B/s]
#
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:01<?, ?B/s]
#
#
#
#   ...p-v4/policy.optimizer.pth: 100% 13.5M/13.5M [00:01<?, ?B/s]
#
#
#
#
#   ...NoFrameskip-v4/policy.pth: 100% 13.5M/13.5M [00:01<?, ?B/s]
#
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip:  99% 26.9M/27.2M [00:00<00:00, 26.2MB/s]
#
#   ...v4/train_eval_metrics.zip: 100% 28.6k/28.6k [00:01<?, ?B/s]
#
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:01<?, ?B/s]
#
#
#
#   ...p-v4/policy.optimizer.pth: 100% 13.5M/13.5M [00:01<?, ?B/s]
#
#
#
#
#   ...NoFrameskip-v4/policy.pth: 100% 13.5M/13.5M [00:01<?, ?B/s]
#
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip:  99% 26.9M/27.2M [00:00<00:00, 17.4MB/s]
#
#   ...v4/train_eval_metrics.zip: 100% 28.6k/28.6k [00:01<?, ?B/s]
#
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:01<?, ?B/s]
#
#
#
#   ...p-v4/policy.optimizer.pth: 100% 13.5M/13.5M [00:01<?, ?B/s]
#
#
#
#
#   ...NoFrameskip-v4/policy.pth: 100% 13.5M/13.5M [00:01<?, ?B/s]
#
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip:  99% 26.9M/27.2M [00:00<00:00, 13.1MB/s]
#
#   ...v4/train_eval_metrics.zip: 100% 28.6k/28.6k [00:01<?, ?B/s]
#
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:01<?, ?B/s]
#
#
#
#   ...p-v4/policy.optimizer.pth: 100% 13.5M/13.5M [00:01<?, ?B/s]
#
#
#
#
#   ...NoFrameskip-v4/policy.pth: 100% 13.5M/13.5M [00:01<?, ?B/s]
#
#
#
#
#
# Processing Files (5 / 5)      : 100% 54.3M/54.3M [00:02<00:00, 17.8MB/s, 15.1MB/s  ]
# New Data Upload               : 100% 281k/281k [00:02<00:00, 140kB/s,  156kB/s  ]
#
#   ...v4/train_eval_metrics.zip: 100% 28.6k/28.6k [00:02<?, ?B/s]
#
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:02<?, ?B/s]
#
#
#
#   ...p-v4/policy.optimizer.pth: 100% 13.5M/13.5M [00:01<?, ?B/s]
#
#
#
#
#   ...NoFrameskip-v4/policy.pth: 100% 13.5M/13.5M [00:01<?, ?B/s]
#
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip: 100% 27.2M/27.2M [00:01<00:00, 8.95MB/s]
#
#   ...v4/train_eval_metrics.zip: 100% 28.6k/28.6k [00:02<?, ?B/s]
#
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:02<?, ?B/s]
#
#
#
#   ...p-v4/policy.optimizer.pth: 100% 13.5M/13.5M [00:02<?, ?B/s]
#
#
#
#
#   ...NoFrameskip-v4/policy.pth: 100% 13.5M/13.5M [00:02<?, ?B/s]
#
#
#
#
#
#   ...nvadersNoFrameskip-v4.zip: 100% 27.2M/27.2M [00:01<00:00, 8.30MB/s]
#
#   ...v4/train_eval_metrics.zip: 100% 28.6k/28.6k [00:02<?, ?B/s]
#
#
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:02<?, ?B/s]
#
#
#
#   ...p-v4/policy.optimizer.pth: 100% 13.5M/13.5M [00:02<?, ?B/s]
#
#
#
#
#   ...NoFrameskip-v4/policy.pth: 100% 13.5M/13.5M [00:02<?, ?B/s]
#
#
#
#
#
# Processing Files (5 / 5)      : 100% 54.3M/54.3M [00:02<00:00, 22.5MB/s, 12.4MB/s  ]
# New Data Upload               : 100% 281k/281k [00:02<00:00, 117kB/s,  128kB/s  ]
#   ...v4/train_eval_metrics.zip: 100% 28.6k/28.6k [00:02<?, ?B/s]
#   ...-v4/pytorch_variables.pth: 100% 1.26k/1.26k [00:02<?, ?B/s]
#   ...p-v4/policy.optimizer.pth: 100% 13.5M/13.5M [00:02<?, ?B/s]
#   ...NoFrameskip-v4/policy.pth: 100% 13.5M/13.5M [00:02<?, ?B/s]
#   ...nvadersNoFrameskip-v4.zip: 100% 27.2M/27.2M [00:01<00:00, 7.67MB/s]
# ℹ Your model is pushed to the hub. You can view your model here:
# https://huggingface.co/KeQingXiaoJieDeGou/dqn-SpaceInvadersNoFrameskip-v4

# %% [markdown]
# ###.

# %% [markdown]
# Congrats 🥳 you've just trained and uploaded your first Deep Q-Learning agent using RL-Baselines-3 Zoo. The script above should have displayed a link to a model repository such as https://huggingface.co/ThomasSimonini/dqn-SpaceInvadersNoFrameskip-v4. When you go to this link, you can:
#
# - See a **video preview of your agent** at the right.
# - Click "Files and versions" to see all the files in the repository.
# - Click "Use in stable-baselines3" to get a code snippet that shows how to load the model.
# - A model card (`README.md` file) which gives a description of the model and the hyperparameters you used.
#
# Under the hood, the Hub uses git-based repositories (don't worry if you don't know what git is), which means you can update the model with new versions as you experiment and improve your agent.
#
# **Compare the results of your agents with your classmates** using the [leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) 🏆

# %% [markdown]
# ## Load a powerful trained model 🔥
# - The Stable-Baselines3 team uploaded **more than 150 trained Deep Reinforcement Learning agents on the Hub**.
#
# You can find them here: 👉 https://huggingface.co/sb3
#
# Some examples:
# - Asteroids: https://huggingface.co/sb3/dqn-AsteroidsNoFrameskip-v4
# - Beam Rider: https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4
# - Breakout: https://huggingface.co/sb3/dqn-BreakoutNoFrameskip-v4
# - Road Runner: https://huggingface.co/sb3/dqn-RoadRunnerNoFrameskip-v4
#
# Let's load an agent playing Beam Rider: https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# 1. We download the model using `rl_zoo3.load_from_hub`, and place it in a new folder that we can call `rl_trained`

# %%
# Download model and save it into the logs/ folder
# !python -m rl_zoo3.load_from_hub --algo dqn --env BeamRiderNoFrameskip-v4 -orga sb3 -f rl_trained/

# %% [markdown]
# 2. Let's evaluate if for 5000 timesteps

# %%
# !python -m rl_zoo3.enjoy --algo dqn --env BeamRiderNoFrameskip-v4 -n 5000  -f rl_trained/ --no-render

# %% [markdown]
# Why not trying to train your own **Deep Q-Learning Agent playing BeamRiderNoFrameskip-v4? 🏆.**
#
# If you want to try, check https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4#hyperparameters **in the model card, you have the hyperparameters of the trained agent.**

# %% [markdown]
# But finding hyperparameters can be a daunting task. Fortunately, we'll see in the next Unit, how we can **use Optuna for optimizing the Hyperparameters 🔥.**

# %% [markdown]
# ## Some additional challenges 🏆
# The best way to learn **is to try things by your own**!
#
# In the [Leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) you will find your agents. Can you get to the top?
#
# Here's a list of environments you can try to train your agent with:
# - BeamRiderNoFrameskip-v4
# - BreakoutNoFrameskip-v4
# - EnduroNoFrameskip-v4
# - PongNoFrameskip-v4
#
# Also, **if you want to learn to implement Deep Q-Learning by yourself**, you definitely should look at CleanRL implementation: https://github.com/vwxyzjn/cleanrl/blob/master/cleanrl/dqn_atari.py
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit4/atari-envs.gif" alt="Environments"/>

# %% [markdown]
# ________________________________________________________________________
# Congrats on finishing this chapter!
#
# If you’re still feel confused with all these elements...it's totally normal! **This was the same for me and for all people who studied RL.**
#
# Take time to really **grasp the material before continuing and try the additional challenges**. It’s important to master these elements and having a solid foundations.
#
# In the next unit, **we’re going to learn about [Optuna](https://optuna.org/)**. One of the most critical task in Deep Reinforcement Learning is to find a good set of training hyperparameters. And Optuna is a library that helps you to automate the search.

# %% [markdown]
# ### This is a course built with you 👷🏿‍♀️
#
# Finally, we want to improve and update the course iteratively with your feedback. If you have some, please fill this form 👉 https://forms.gle/3HgA7bEHwAmmLfwh9
#
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# See you on Bonus unit 2! 🔥

# %% [markdown]
# ### Keep Learning, Stay Awesome 🤗
